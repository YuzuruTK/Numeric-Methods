# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Colocar o Intervalo entre os Pontos desejados
intervalo = [0,-0.5]

# X inicial
x0 = 0
# Y inicial
y0 = -1
# intervalo entre valores
h = 0.1

def function_x(x, y):
    # Set da Função
    return ((-2 * x) - y)

# %%
x_values = [x0]
y_values = [y0]


iteration_range = np.sqrt((intervalo[0] - intervalo[1]) ** 2) / h

values = [[x0,y0]]

for i in range(0,int(iteration_range)):

    x = intervalo[0] + h*(i+1) 
    y = y_values[i] + h * function_x(x_values[i], y_values[i])
    
    x_values.append(x)
    y_values.append(y)

    values.append([x,y])

# %%
dataframe = pd.DataFrame(data=values, columns=["x","y"])

print(dataframe)

sns.scatterplot(data=dataframe, x="x", y="y")
sns.lineplot(data=dataframe, x="x", y="y")
# Out:
#      x        y
# 0  0.0 -1.00000
# 1  0.1 -0.90000
# 2  0.2 -0.83000
# 3  0.3 -0.78700
# 4  0.4 -0.76830
# 5  0.5 -0.77147
# <Axes: xlabel='x', ylabel='y'>
